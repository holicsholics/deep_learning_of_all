# %%
# -*- coding: utf-8 -*-
# 코드 내부에 한글을 사용가능 하게 해주는 부분입니다.

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt("../dataset/ThoraricSurgery.csv", delimiter=",")

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정합니다(모델을 설정하고 실행하는 부분입니다).
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝을 실행합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 581us/step - loss: 1.3494 - accuracy: 0.7915
# Epoch 2/100
# 47/47 [==============================] - 0s 528us/step - loss: 0.8821 - accuracy: 0.8170
# Epoch 3/100
# 47/47 [==============================] - 0s 496us/step - loss: 0.6574 - accuracy: 0.8170
# Epoch 4/100
# 47/47 [==============================] - 0s 487us/step - loss: 0.5289 - accuracy: 0.8340
# Epoch 5/100
# 47/47 [==============================] - 0s 499us/step - loss: 0.4652 - accuracy: 0.8426
# Epoch 6/100
# 47/47 [==============================] - 0s 477us/step - loss: 0.4347 - accuracy: 0.8532
# Epoch 7/100
# 47/47 [==============================] - 0s 489us/step - loss: 0.4540 - accuracy: 0.8468
# Epoch 8/100
# 47/47 [==============================] - 0s 486us/step - loss: 0.4443 - accuracy: 0.8532
# Epoch 9/100
# 47/47 [==============================] - 0s 500us/step - loss: 0.4241 - accuracy: 0.8532
# Epoch 10/100
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import tensorflow as tf
import os

np.random.seed(3)
tf.random.set_seed(3)

# %%
# ..은 상위 경로로 가는 것
data = np.loadtxt("../dataset/ThoraricSurgery.csv", delimiter = ",")

# %%
# 현재 경로 확인
os.getcwd()
# Out:
# '/Users/sangu/Desktop/모두의딥러닝/080228-master/deeplearning/run_project'

# %%
# 경로 수정 한 개 앞으로
os.chdir('/Users/sangu/Desktop/모두의딥러닝/080228-master/deeplearning')

# %%
os.getcwd()
# Out:
# '/Users/sangu/Desktop/모두의딥러닝/080228-master/deeplearning'

# %%
# deeplearning 경로로 가서 dataset으로 바로 불러올 수 있었음
data = np.loadtxt("dataset/ThoraricSurgery.csv", delimiter = ",")

# %%
data.shape
# Out:
# (470, 18)

# %%
X = data[:,0:17]
Y = data[:,17]

# %%
model = Sequential()

# %%
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = "sigmoid"))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam',
             metrics = ['accuracy'])
model.fit(X,Y, epochs = 100, batch_size = 10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 614us/step - loss: 3.6082 - accuracy: 0.6362
# Epoch 2/100
# 47/47 [==============================] - 0s 552us/step - loss: 0.8288 - accuracy: 0.7128
# Epoch 3/100
# 47/47 [==============================] - 0s 509us/step - loss: 0.5733 - accuracy: 0.7787
# Epoch 4/100
# 47/47 [==============================] - 0s 496us/step - loss: 0.5344 - accuracy: 0.8064
# Epoch 5/100
# 47/47 [==============================] - 0s 497us/step - loss: 0.4924 - accuracy: 0.8298
# Epoch 6/100
# 47/47 [==============================] - 0s 505us/step - loss: 0.4601 - accuracy: 0.8426
# Epoch 7/100
# 47/47 [==============================] - 0s 515us/step - loss: 0.4661 - accuracy: 0.8511
# Epoch 8/100
# 47/47 [==============================] - 0s 510us/step - loss: 0.4722 - accuracy: 0.8447
# Epoch 9/100
# 47/47 [==============================] - 0s 507us/step - loss: 0.4399 - accuracy: 0.8489
# Epoch 10/100
# ...

# %%
# loss 값 0.409 accuracy 값 0.83
# loss 는 예측이 빗나간 정도,
# accuracy 는 예측이 성공할 확률

# %%
data
# Out:
# array([[293.  ,   1.  ,   3.8 , ...,   0.  ,  62.  ,   0.  ],
#        [  1.  ,   2.  ,   2.88, ...,   0.  ,  60.  ,   0.  ],
#        [  8.  ,   2.  ,   3.19, ...,   0.  ,  66.  ,   1.  ],
#        ...,
#        [406.  ,   6.  ,   5.36, ...,   0.  ,  62.  ,   0.  ],
#        [ 25.  ,   8.  ,   4.32, ...,   0.  ,  58.  ,   1.  ],
#        [447.  ,   8.  ,   5.2 , ...,   0.  ,  49.  ,   0.  ]])

# %%
# 총 18개의 열이 있다.
# 17개의 열은 속성(attribute), 18번째 열은 클래스(class)라고 부른다.
# 딥러닝을 구동하려면 속성만을 뽑아 데이터 셋을 만들고 클래스를 담는 데이터셋을 또 따로 만들어 줘야한다.

# %%
X = data[:,0:17]
Y = data[:,17]

# %%
# Sequential() 함수는 딥러닝의 구조를 한 층 한 층 쉽게 쌓아 올릴 수 있게 해준다.
# 그 후 model.add()함수를 사용해 필요한 층을 추가함
